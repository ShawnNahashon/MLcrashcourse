# %%
# Importing the data from the dataset

import pandas as pd
ds = pd.read_excel('diabetes.xlsx')

# %%
# printing only the PatientID of the first 7 diabetic patients

ds.PatientID.head(7)
# Out:
# 0    1354778
# 1    1147438
# 2    1640031
# 3    1883350
# 4    1424119
# 5    1619297
# 6    1660149
# Name: PatientID, dtype: int64

# %%
# Deleting column that will not be of any use when building a machine learning model
ds = ds.drop(columns = 'TricepsThickness')
ds.head(10)
# Out:
#    PatientID  Pregnancies  PlasmaGlucose  DiastolicBloodPressure  \
# 0    1354778            0            171                      80
# 1    1147438            8             92                      93
# 2    1640031            7            115                      47
# 3    1883350            9            103                      78
# 4    1424119            1             85                      59
# 5    1619297            0             82                      92
# 6    1660149            0            133                      47
# 7    1458769            0             67                      87
# 8    1201647            8             80                      95
# 9    1403912            1             72                      31
#
#    SerumInsulin        BMI  DiabetesPedigree  Age  Diabetic
# 0            23  43.509726          1.213191   21         0
# 1            36  21.240576          0.158365   23         0
# 2            35  41.511523          0.079019   23         0
# 3           304  29.582192          1.282870   43         1
# 4            35  42.604536          0.549542   22         0
# 5           253  19.724160          0.103424   26         0
# 6           227  21.941357          0.174160   21         0
# 7            36  18.277723          0.236165   26         0
# 8            24  26.624929          0.443947   53         1
# 9            42  36.889576          0.103944   26         0

# %%
# Creating a histogram using pandas of the column DiastolicBloodPressure
ds.hist(column = 'DiastolicBloodPressure')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x119ff7a90>]],
#       dtype=object)

# %%
# Pie chart representing diabetic and non diabetic proportion
import matplotlib.pyplot as plt
Diabetic = ds[ds['Diabetic'] == 1]
Non_Diabetic = ds[ds['Diabetic'] == 0]
count = [len(Diabetic), len(Non_Diabetic)]
print(count)

condition = ['Diabetic', 'Non_Diabetic']
colors = ('g', 'r')
plt.pie(count, labels = condition, colors = colors, autopct = '%1.1f%%')
plt.show()
# Out:
# [5000, 10000]

# %%
# printing number of people who are non-diabetic
print("Non-Diabetic people in the dataset are: ", len(Non_Diabetic))
# Out:
# Non-Diabetic people in the dataset are:  10000

# %%
# selecting rows where number of pregnancies is greater than 5
ds[ds.Pregnancies > 5]
# Out:
#        PatientID  Pregnancies  PlasmaGlucose  DiastolicBloodPressure  \
# 1        1147438            8             92                      93
# 2        1640031            7            115                      47
# 3        1883350            9            103                      78
# 8        1201647            8             80                      95
# 13       1669231            7            110                      82
# 18       1536832            8            117                      39
# 25       1710438            9            104                      68
# 26       1139740            6            135                      91
# 30       1121857           11             75                      89
# 31       1117458            8            152                      83
# 35       1411676            7             45                      66
# 39       1798712            7            108                      95
# 47       1882185            9            104                      51
# 48       1662484            6             73                      61
# 56       1439246            7            121                      54
# 57       1935749            9            125                      79
# 59       1307013            9             78                      50
# 60       1011054            9             67                      78
# 62       1995399            9             56                      87
# 63       1988885            7             87                      57
# 68       1074476            9             79                      43
# 75       1693341            7             76                      82
# 78       1302648            8            105                      61
# 82       1430156            7             90                      58
# 85       1520875            6             93                      78
# 88       1378266            7             84                      65
# 93       1504272            6            127                      85
# 99       1882910            9             96                      73
# 101      1864422            9             88                      85
# 105      1722612            7             85                      95
# ...          ...          ...            ...                     ...
# 14904    1765368           12            117                      60
# 14906    1246300            6            124                      92
# 14908    1208058            8            175                      80
# 14975           224  38.903552          0.133446   22         0
# 14978           387  20.858520          0.899682   22         1
# 14979           186  20.642572          0.745377   43         0
# 14980            21  19.321562          0.614377   23         0
# 14982           412  38.204487          0.199657   21         1
# 14983           214  19.138671          0.143024   22         1
# 14984            63  51.877294          0.172106   44         1
# 14986            80  36.680032          0.200504   22         1
# 14989           128  20.647840          0.265326   43         0
# 14995           177  33.512468          0.148327   41         1
#
# [4239 rows x 9 columns]

# %%
# selecting third cell in the row named BMI
ds.iloc[2],['BMI']
# Out:
# (PatientID                 1.640031e+06
#  Pregnancies               7.000000e+00
#  PlasmaGlucose             1.150000e+02
#  DiastolicBloodPressure    4.700000e+01
#  SerumInsulin              3.500000e+01
#  BMI                       4.151152e+01
#  DiabetesPedigree          7.901857e-02
#  Age                       2.300000e+01
#  Diabetic                  0.000000e+00
#  Name: 2, dtype: float64, ['BMI'])

# %%
# Printing names of all the columns
column_names = list(ds.head(0))
print(column_names)
# Out:
# ['PatientID', 'Pregnancies', 'PlasmaGlucose', 'DiastolicBloodPressure', 'SerumInsulin', 'BMI', 'DiabetesPedigree', 'Age', 'Diabetic']

# %%
# printing datatype of each columns
ds.dtypes
# Out:
# PatientID                   int64
# Pregnancies                 int64
# PlasmaGlucose               int64
# DiastolicBloodPressure      int64
# SerumInsulin                int64
# BMI                       float64
# DiabetesPedigree          float64
# Age                         int64
# Diabetic                    int64
# dtype: object

# %%
# Summarizing the columns
ds.describe()
# Out:
#           PatientID   Pregnancies  PlasmaGlucose  DiastolicBloodPressure  \
# count  1.500000e+04  15000.000000   15000.000000            15000.000000
# mean   1.502922e+06      3.224533     107.856867               71.220667
# std    2.892534e+05      3.391020      31.981975               16.758716
# min    1.000038e+06      0.000000      44.000000               24.000000
# 25%    1.252866e+06      0.000000      84.000000               58.000000
# 50%    1.505508e+06      2.000000     104.000000               72.000000
# 75%    1.755205e+06      6.000000     129.000000               85.000000
# max    1.999997e+06     14.000000     192.000000              117.000000
#
#        SerumInsulin           BMI  DiabetesPedigree           Age  \
# count  15000.000000  15000.000000      15000.000000  15000.000000
# mean     137.852133     31.509646          0.398968     30.137733
# std      133.068252      9.759000          0.377944     12.089703
# min       14.000000     18.200512          0.078044     21.000000
# 25%       39.000000     21.259887          0.137743     22.000000
# 50%       83.000000     31.767940          0.200297     24.000000
# 75%      195.000000     39.259692          0.616285     35.000000
# max      799.000000     56.034628          2.301594     77.000000
#
#            Diabetic
# count  15000.000000
# mean       0.333333
# std        0.471420
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000

# %%
#visualizing relationship between age and an individual being diabetic or not
# %matplotlib inline
X = ds['Diabetic'].groupby(ds['Age']).sum()
Y = ds['Diabetic'].groupby(ds['Age']).count()
plt.plot(X, linewidth = 2.5,color = '#1f77b4')
plt.plot(Y, linewidth = 2.5,color = '#ff7f0e')
plt.title("Relationship between age and diabetes", fontsize = 12)
plt.ylabel("Number of diabetics", fontsize = 12)
# Out:
# Text(0, 0.5, 'Number of diabetics')

# %%
a = ds[ds['Age'] == 21]
print(len(a))
# Out:
# 2556
